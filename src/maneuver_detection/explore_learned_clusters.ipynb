# %% [markdown]
# ## ce notebook a pour but d'explorer les params orbitaux des clusters appris par apprentissage non supervisé sur les données spacetrack

# %%
import os
import pandas as pd
from pathlib import Path
import csv

from viz.time_series import plot_cluster, plot_time_series, plot_compare

base = Path.cwd()

# %%
spacetrack_data_dir = Path(os.path.join(base , '..', '..', 'data', 'raw', 'spacetrack', 'max_objects_all_regimes'))


dataframes = sorted(spacetrack_data_dir.glob("*.parquet"))

df_TLE = pd.concat([pd.read_parquet(p) for p in dataframes], ignore_index = True)

# %%
import matplotlib.pyplot as plt
import re 
import gc 

CLUSTER_DIR = os.path.join(base, '..', '..', 'outputs', 'clustering' , 'cluster_leo_15000_128D_MCS15_MS15_OPTIM_named.csv')
figures_dir = Path(os.path.join(base, '..', '..', 'outputs', 'clustering'))

def sanitize_filename(filename):
    """Remplace les caractères interdits dans un nom de fichier."""
    # Garde seulement alphanumérique, espace, underscore, tiret
    return re.sub(r'[^\w\-_ ]', '_', filename)


def learned_clusters_params(cluster_dir, df_tle) : 

    df_cluster = pd.read_csv(cluster_dir)
    valid = df_cluster[df_cluster['cluster'] != -1]
    norads = valid['norad']

    df_tle_valid= df_tle[df_tle['norad'].isin(norads)]
    
    for cluster_id, sub in valid.groupby('cluster') : 
        norads = sub['norad']
        cluster_name = sub['cluster_name'].iloc[0] 
        cluster_label = f'Cluster {cluster_id} : {len(norads)} objets, {cluster_name}'
        fig = plot_cluster(
            df_tle_valid, 
            norads, 
            ['sma' , 'inclination' , 'eccentricity', 'raan', 'arg_perigee', 'mean_anomaly'], 
            cluster_label=cluster_label
            )
        label = sanitize_filename(cluster_label)
        fig_name = figures_dir / f"{label}.png"
        fig.savefig(fig_name)
        print(f"fichier {fig_name}")
        plt.close(fig)
        del fig, norads, sub, cluster_name, cluster_label, label
        gc.collect()  # Force le garbage collector

learned_clusters_params(CLUSTER_DIR, df_TLE)
# Out:
# /home/echevrolat/Documents/dev/ssa-analysis/src/viz/time_series.py:343: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax.legend(fontsize=7, loc="upper right", framealpha=0.7)
# fichier /home/echevrolat/Documents/dev/ssa-analysis/src/maneuver_detection/../../outputs/clustering/Cluster 0 _ 25 objets_ Starlink _SpaceX_ - propulsion electrique Hall argon - lot de lancement unique 2026 _25 sats_.png
# fichier /home/echevrolat/Documents/dev/ssa-analysis/src/maneuver_detection/../../outputs/clustering/Cluster 1 _ 25 objets_ Starlink _SpaceX_ - propulsion electrique Hall argon - lot de lancement unique 2026 _25 sats_.png
# fichier /home/echevrolat/Documents/dev/ssa-analysis/src/maneuver_detection/../../outputs/clustering/Cluster 2 _ 123 objets_ Yaogan 9_16_etc _triplets surveillance navale_ CN_ _ payloads anciens - propulsion chimique - _1100 km _ 63_4deg.png
# fichier /home/echevrolat/Documents/dev/ssa-analysis/src/maneuver_detection/../../outputs/clustering/Cluster 3 _ 71 objets_ Payloads anciens 1986-2000 - propulsion chimique ou nulle.png
# fichier /home/echevrolat/Documents/dev/ssa-analysis/src/maneuver_detection/../../outputs/clustering/Cluster 4 _ 53 objets_ Starlink _SpaceX_ - propulsion electrique Hall argon - lots de lancement 2026.png
# fichier /home/echevrolat/Documents/dev/ssa-analysis/src/maneuver_detection/../../outputs/clustering/Cluster
km.png
# fichier /home/echevrolat/Documents/dev/ssa-analysis/src/maneuver_detection/../../outputs/clustering/Cluster 28 _ 36 objets_ Payloads anciens multi-epoques - propulsion chimique ou nulle.png
# fichier /home/echevrolat/Documents/dev/ssa-analysis/src/maneuver_detection/../../outputs/clustering/Cluster 29 _ 53 objets_ OneWeb _Eutelsat OneWeb_ - propulsion electrique Hall xenon - plan orbital polaire 87_9deg _ 1200 km.png
# fichier /home/echevrolat/Documents/dev/ssa-analysis/src/maneuver_detection/../../outputs/clustering/Cluster 30 _ 61 objets_ OneWeb _Eutelsat OneWeb_ - propulsion electrique Hall xenon - plan orbital polaire 87_9deg _ 1200 km.png
# fichier /home/echevrolat/Documents/dev/ssa-analysis/src/maneuver_detection/../../outputs/clustering/Cluster 31 _ 50 objets_ OneWeb _Eutelsat OneWeb_ - propulsion electrique Hall xenon - plan orbital polaire 87_9deg _ 1200 km.png
# fichier /home/echevrolat/Documents/dev/ssa-analysis/src/maneuver_detection/../../outputs/clustering/Cluster 32 _ 53 objets_ OneWeb _Eutelsat OneWeb_ - propulsion electrique Hall xenon - plan orbital polaire 87_9deg _ 1200 km.png
# fichier /home/echevrolat/Documents/dev/ssa-analysis/src/maneuver_detection/../../outputs/clustering/Cluster 33 _ 56 objets_ OneWeb _Eutelsat OneWeb_ - propulsion electrique Hall xenon - plan orbital polaire 87_9deg _ 1200 km.png
# fichier /home/echevrolat/Documents/dev/ssa-analysis/src/maneuver_detection/../../outputs/clustering/Cluster 34 _ 51 objets_ OneWeb _Eutelsat OneWeb_ - propulsion electrique Hall xenon - plan orbital polaire 87_9deg _ 1200 km.png
# fichier /home/echevrolat/Documents/dev/ssa-analysis/src/maneuver_detection/../../outputs/clustering/Cluster 35 _ 51 objets_ OneWeb _Eutelsat OneWeb_ - propulsion electrique Hall xenon - plan orbital polaire 87_9deg _ 1200 km.png
# fichier /home/echevrolat/Documents/dev/ssa-analysis/src/maneuver_detection/../../outputs/clustering/Cluster 36 _ 58 objets_ OneWeb _Eutelsat OneWeb_ - propulsion electrique Hall xenon - plan orbital polaire 87_9deg _ 1200 km.png
# fichier /home/echevrolat/Documents/dev/ssa-analysis/src/maneuver_detection/../../outputs/clustering/Cluster 37 _ 51 objets_ OneWeb _Eutelsat OneWeb_ - propulsion electrique Hall xenon - plan orbital polaire 87_9deg _ 1200 km.png
# fichier /home/echevrolat/Documents/dev/ssa-analysis/src/maneuver_detection/../../outputs/clustering/Cluster 38 _ 56 objets_ OneWeb _Eutelsat OneWeb_ - propulsion electrique Hall xenon - plan orbital polaire 87_9deg _ 1200 km.png
# fichier /home/echevrolat/Documents/dev/ssa-analysis/src/maneuver_detection/../../outputs/clustering/Cluster 39 _ 54 objets_ OneWeb _Eutelsat OneWeb_ - propulsion electrique Hall xenon - plan orbital polaire 87_9deg _ 1200 km.png
# fichier /home/echevrolat/Documents/dev/ssa-analysis/src/maneuver_detection/../../outputs/clustering/Cluster 40 _ 88 objets_ Payloads historiques 1970-1990 - propulsion chimique ou nulle.png
# fichier /home/echevrolat/Documents/dev/ssa-analysis/src/maneuver_detection/../../outputs/clustering/Cluster 41 _ 76 objets_ Payloads historiques 1980-1990 - propulsion chimique ou nulle.png
# fichier /home/echevrolat/Documents/dev/ssa-analysis/src/maneuver_detection/../../outputs/clustering/Cluster 42 _ 40 objets_ Guowang _ SatNet _CN_ HULIANWANG DIGUI_ - propulsion electrique - _ Chuang Xin _ HJS.png
# fichier /home/echevrolat/Documents/dev/ssa-analysis/src/maneuver_detection/../../outputs/clustering/Cluster 43 _ 17 objets_ Guowang _ SatNet _CN_ HULIANWANG DIGUI_ - propulsion electrique - lot 2025.png
# fichier /home/echevrolat/Documents/dev/ssa-analysis/src/maneuver_detection/../../outputs/clustering/Cluster 44 _ 18 objets_ Guowang _ SatNet _CN_ HULIANWANG DIGUI_ - propulsion electrique - lot 2026.png
# fichier /home/echevrolat/Documents/dev/ssa-analysis/src/maneuver_detection/../../outputs/clustering/Cluster 45 _ 230 objets_ Yaogan-30 _triplets ELINT_ CN_ _ GeeSat _Geely_ _ Tianqi - propulsion chimique - LEO _600 km _ 35deg.png
# fichier /home/echevrolat/Documents/dev/ssa-analysis/src/maneuver_detection/../../outputs/clustering/Cluster 46 _ 21 objets_ Starlink _SpaceX_ - propulsion electrique Hall argon - lot de lancement 2026 _21 sats_.png
# fichier /home/echevrolat/Documents/dev/ssa-analysis/src/maneuver_detection/../../outputs/clustering/Cluster 47 _ 96 objets_ Starlink _SpaceX_ - propulsion electrique Hall probable - coquille heterogene non confirmee.png
